# %% [markdown]
# Importing Necessary Files

# %%
import numpy as np # for handling arrays if needed
import pandas as pd # for handling the dataframes and matrices
import matplotlib.pyplot as plt # for visualisation
import seaborn as sns # for clear in statistical visualisation

# %% [markdown]
# loading data set and gaining the information over the datset by initial exploration for further Preprocessing

# %%
prime_Data = pd.read_csv("/content/prime.csv") #Loading up the dataset

# %%
prime_Data.head(10) # it gives the first 10 datas with its features as columns for looking up the data samples for further analysis
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
prime_Data.info() #gaining up the data information of what are the features and what are up over there
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
prime_Data.describe() # gives up the summary statistics , it describes the summary stat for the numerical column
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
prime_Data.describe(include="all") # this gives up the summary statistics for both numeric and categorical values over the data
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7982           7976             8797   8807.000000
# unique                7692            748             1767           NaN
# ...

# %%
prime_Data.count() # so as we saw in above count gives the non-missing value
# Out:
# show_id         8807
# type            8807
# title           8807
# director        6173
# cast            7982
# country         7976
# date_added      8797
# release_year    8807
# rating          8803
# duration        8804
# listed_in       8807
# description     8807
# dtype: int64

# %% [markdown]
# Finding Duplicates

# %%
prime_Data[prime_Data.duplicated()] # to find up the duplicates over the column
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# Handling Nan

# %%
prime_Data.isnull().sum() #This Shows the sum of the Nan values accross the dataset accornding to its column
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
prime_Data['director'].unique() #we can see the nan value so we can impute it
prime_Data['director'].isnull().sum() #we can see the nan count
# Out:
# 2634

# %%
prime_Data['director'].fillna('Missing',inplace=True) #we can do the Arbitary imputation technique as it is of categorical data

# %%
prime_Data['director'].unique() #nan is imputed into missing
prime_Data['director'].isnull().sum() #Here we can see the nan count after imputing
# Out:
# 0

# %% [markdown]
# As of we can impute Arbitary Imputation for cast , country , rating , duration

# %%
prime_Data['cast'].fillna('Missing',inplace=True) #imputing cast feature

# %%
prime_Data.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast              0
# country         831
# date_added       10
# release_year      0
# rating            4
# duration          3
# listed_in         0
# description       0
# dtype: int64

# %%
prime_Data['country'].fillna('Missing',inplace=True) #imputing country feature

# %%
prime_Data.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           4
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
prime_Data['rating'].fillna('Missing',inplace=True) #imputing rating feature

# %%
prime_Data['duration'].fillna('Missing',inplace=True) #imputing duration feature

# %%
prime_Data.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           0
# duration         0
# listed_in        0
# description      0
# dtype: int64

# %% [markdown]
# Format data

# %%
prime_Data['date_added'].head()
# Out:
# 0    September 25, 2021
# 1    September 24, 2021
# 2    September 24, 2021
# 3    September 24, 2021
# 4    September 24, 2021
# Name: date_added, dtype: object

# %%
prime_Data['date_added '] = pd.to_datetime(prime_Data['date_added']) #this changes the format of the date_added to datetime datatype

# %%
prime_Data['date_added '].head()
# Out:
# 0   2021-09-25
# 1   2021-09-24
# 2   2021-09-24
# 3   2021-09-24
# 4   2021-09-24
# Name: date_added , dtype: datetime64[ns]

# %%
prime_Data['date_added'].isnull().sum()
# Out:
# 10

# %%
prime_Data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Missing
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Missing
# 4      s5  TV Show           Kota Factory          Missing
#
#                                                 cast        country  \
# 0                                            Missing  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Missing
# 3                                            Missing        Missing
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
prime_Data.drop(columns=['date_added'] ,inplace=True) #we drop the old date added column format

# %%
prime_Data['date_added '].fillna('ffill',inplace=True) #this is also an imputation where datetime nan is imputed with the previous non-missing value

# %%
prime_Data['date_added '].isnull().sum() #imputed succesfully
# Out:
# 0

# %%
prime_Data.isnull().sum()#every nan values are imputed successfully
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# date_added      0
# dtype: int64

# %% [markdown]
# Visualization

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=prime_Data ,x='release_year') #release year view
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=prime_Data ,x='type') #comparing Content
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.countplot(data=prime_Data ,x='rating' , order=prime_Data['rating'].value_counts().index) # comparing ratings
plt.show()

# %%
plt.figure(figsize=(45,20))
sns.countplot(data=prime_Data ,x='country' , order=prime_Data['country'].value_counts().index[:20]) # comparing countries and aquiring top 20 countries
plt.show()
